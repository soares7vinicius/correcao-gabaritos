# %%
# 1 - 120
# 01 16 31 46
# 02 17 32 47

# %%
a = list(range(1, 121))
b = []

offset = 0
cont = 0
for i in range(60):
    b.append(a[offset])
    
    if cont == 3:
        cont = 0
        offset -= 44
    else:
        cont += 1
        offset += 15

offset = 60
cont = 0
for i in range(60):
    b.append(a[offset])
    
    if cont == 3:
        cont = 0
        offset -= 44
    else:
        cont += 1
        offset += 15

# %%
b
# Out:
# [1,
#  16,
#  31,
#  46,
#  2,
#  17,
#  32,
#  47,
#  3,
#  18,
#  33,
#  48,
#  4,
#  19,
#  34,
#  49,
#  5,
#  20,
#  35,
#  50,
#  6,
#  21,
#  36,
#  51,
#  7,
#  22,
#  37,
#  52,
#  8,
#  23,
#  38,
#  53,
#  9,
#  24,
#  39,
#  54,
#  10,
#  25,
#  40,
#  55,
#  11,
#  26,
#  41,
#  56,
#  12,
#  27,
#  42,
#  57,
#  13,
#  28,
#  43,
#  58,
#  14,
#  29,
#  44,
#  59,
#  15,
#  30,
#  45,
#  60,
#  61,
#  76,
#  91,
#  106,
#  62,
#  77,
#  92,
#  107,
#  63,
#  78,
#  93,
#  108,
#  64,
#  79,
#  94,
#  109,
#  65,
#  80,
#  95,
#  110,
#  66,
#  81,
#  96,
#  111,
#  67,
#  82,
#  97,
#  112,
#  68,
#  83,
#  98,
#  113,
#  69,
#  84,
#  99,
#  114,
#  70,
#  85,
#  100,
#  115,
#  71,
#  86,
#  101,
#  116,
#  72,
#  87,
#  102,
#  117,
#  73,
#  88,
#  103,
#  118,
#  74,
#  89,
#  104,
#  119,
#  75,
#  90,
#  105,
#  120]
